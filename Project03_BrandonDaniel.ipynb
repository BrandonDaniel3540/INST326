# %% [markdown]
# ### INST326 OOP Project 03

# %% [markdown]
# Rename this notebook, replacing "_Assignment" with "_YourName"<br>
# INST326 Group 47 - Brandon, Megan and Albi<br>
# Insert Signature Block Here

# %% [markdown]
# ### Brandon Daniel, Albi Ndrenika, Megan Otchet
# > INST326 Section 0104
# > Group number 47<br>
# > OOP Project 03
# > November 17th, 2024
# #### Honor Pledge
# > I pledge that the work contained in this assignment is my own, and that I have complied with University and course policies on academic integrity, and AI use.
# #### Disclosures and Citations
# > ChatGPT, response to the prompt "Can you make a basic html calendar that you can change using python code and you can put into it's own python class?." OpenAI, November 19, 2024.<br>
# > ChatGPT, response to the prompt "How do I enter text under each date on the calendar?" OpenAI, November 20, 2024.

# %% [markdown]
# ### The Project
# Everyone will do the same project this time. This is a group project, so you must work in your assigned groups. Include the link to your group's GitHub repository (one link per group). Use comments in your code to document your solution. If you need to write comments to the grader, add a markdown cell immediately above your code solution and add your comments there. Be sure to read and follow all the requirements and the Notebook Instructions at the bottom of this notebook. Your grade may depend on it!

# %% [markdown]
# #### 1. A Scheduling Program
# >  My wife is responsible for scheduling caregivers for her 93 year-old mother. Currently she writes out the schedule on a monthly calendar and photocopies it for everyone. I want all of you to help me write a program to help her with scheduling. While this is a specific application, this program will be broadly useful and adaptable to any scheduling needs for small businesses, clubs, and more.

# %% [markdown]
# #### Requirements
# >  Care is required 12 hours per day, 7 days a week. There are two shifts each day: 7:00 AM - 1:00 PM, and 1:00 PM to 7:00 PM. There are a total of 8 caregivers. Some are family members and some are paid. Each caregiver has their own availability for shifts that is generally the same from month to month, but there are exceptions for work, vacations, and other responsibilities. Your program should do the following:
# > 1. Manage caregivers and their schedules. Attributes include: name, phone, email, pay rate, and hours.
# > 2. Each caregiver should have their own availability schedule where they can indicate their availability for each shift. Availability categories are 'preferred', 'available' (default), and 'unavailable'.
# > 3. Create a care schedule that covers AM and PM shifts and displays caregiver names on a calendar (see example). The schedule should accomodate caregivers' individual schedules and availability preferences. The python calendar module provides options for creating HTML calendars. Sample code for the HTML calendar is in the project folder.
# > 4. Paid caregivers are paid weekly at $20/hr. Your program should calculate weekly pay based on assigned hours. Provide a separate pay report that lists weekly (gross: hours x rate) amounts to each caregiver, along with weekly and monthly totals. The report can be a text document, or presented in GUI or HTML format.

# %% [markdown]
# #### Group Requirements
# >  1. Your submitted project should follow OOP principles like abstraction, encapsulation, inheritance, and polymorphism as appropriate. Your program should use classes.
# >  2. Select a group leader who will host the group's project repository on their GitHub.
# >  3. Create the group repository and add a main program document. See example.
# >  4. Create branches off the main program for each group member, and assign part of the program to each member.
# >  5. Each member should work on their branch.
# >  6. When each member is finished, merge the branches back into the main program. You may use 'merge' or 'pull requests', your choice.
# >  7. iterate and debug as necessary.

# %% [markdown]
# #### Working with HTML
# > Since this is a course on python, not HTML, you are not expected to know HTML. Therefore, you may copy applicable portions of the sample code or use AI to write the HTML portions of your application. Ypu should write the main python code yourself.

# %% [markdown]
# #### What you need to turn in
# >  This is a group project. There will be one submission per group. Your submission will be graded as a group.
# >  1. Include your group number and the names of all group members in the signature block at the top of this notebook.
# >  2. In the cell below, paste the link to your project repository. One link per group. The grader will review the activity and history provided by GitHub. To add a hyperlink to a Jupyter markdown cell, follow the instructions in the cell below.
# >  3. Below the GitHub Repository Link cell is a code cell. Copy and paste your final program code into this cell.

# %% [markdown]
# #### GitHub Repository Link
# > Example: [INST326 Group 47](https://github.com/BrandonDaniel3540/INST326.git)
# >
# > Edit the link code below with your information, then run this cell. Test the link! It should take you to your GitHub project repository.
# > [external link text](http://url_here)

# %%
import calendar
from datetime import datetime
import random

class Caregiver:
    def __init__(self, name, phone, email, pay_rate, hours):
        self.name = name
        self.phone = phone
        self.email = email
        self.pay_rate = pay_rate
        self.hours = hours

    def get_name(self):
        return self.name

    def set_name(self, name):
        self.name = name

    def get_phone(self):
        return self.phone

    def set_phone(self, phone):
        self.phone = phone
    
    def get_email(self):
        return self.email

    def set_email(self, email):
        self.email = email

    def get_pay_rate(self):
        return self.pay_rate

    def set_pay_rate(self, pay_rate):
        self.pay_rate = pay_rate

    def get_hours(self):
        return self.hours

    def set_hours(self, hours):
        self.hours = hours

class AvailabilitySchedule:
    def __init__(self, name, monday="Available", tuesday="Available", wednesday="Available", thursday="Available", friday="Available", saturday="Available", sunday="Available"):
        self.name = name
        self.monday = monday
        self.tuesday = tuesday
        self.wednesday = wednesday
        self.thursday = thursday
        self.friday = friday
        self.saturday = saturday
        self.sunday = sunday

    def get_schedule(self):
        print(f"\nCaregiver name: {self.name}\nAvailability:\nMonday: {self.monday}\nTuesday: {self.tuesday}\nWednesday: {self.wednesday}\nThursday: {self.thursday}\nFriday: {self.friday}\nSaturday: {self.saturday}\nSunday: {self.sunday}\n")

    def CreateAvailabilitySchedule(self):
        
        SundayAvailable = input(f"Is {self.name} available on Sunday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular:")
        if SundayAvailable == "Available":
            AvailableSunday.append(self.name)
        elif SundayAvailable == "Preferred":
            self.sunday = "Preferred"
            AvailableSunday.append(self.name)
        else:
            UnavailableSunday.append(self.name)
            self.sunday = "Unavailable"
        
        MondayAvailable = input(f"Is {self.name} available on Monday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular:" )
        if MondayAvailable == "Available":
            AvailableMonday.append(self.name)
        elif MondayAvailable == "Preferred":
            self.monday = "Preferred"
            AvailableMonday.append(self.name)
        else:
            UnavailableMonday.append(self.name)
            self.monday = "Unavailable"

        TuesdayAvailable = input(f"Is {self.name} available on Tuesday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular:")
        if TuesdayAvailable == "Available":
            AvailableTuesday.append(self.name)
        elif TuesdayAvailable == "Preferred":
            AvailableTuesday.append(self.name)
            self.tuesday = "Preferred"
        else:
            UnavailableTuesday.append(self.name)
            self.tuesday = "Unavailable"

        WednesdayAvailable = input(f"Is {self.name} available on Wednesday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular:" )
        if WednesdayAvailable == "Available":
            AvailableWednesday.append(self.name)
        elif WednesdayAvailable == "Preferred":
            self.wednesday = "Preferred"
            AvailableWednesday.append(self.name)
        else:
            UnavailableWednesday.append(self.name)
            self.wednesday = "Unavailable"

        ThursdayAvailable = input(f"Is {self.name} available on Thursday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular:" )
        if ThursdayAvailable == "Available":
            AvailableThursday.append(self.name)
        elif ThursdayAvailable == "Preferred":
            self.thursday = "Preferred"
            AvailableThursday.append(self.name)
        else:
            UnavailableThursday.append(self.name)
            self.thursday = "Unavailable"

        FridayAvailable = input(f"Is {self.name} available on Friday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular:" )
        if FridayAvailable == "Available":
            AvailableFriday.append(self.name)
        elif FridayAvailable == "Preferred":
            self.friday = "Preferred"
            AvailableFriday.append(self.name)
        else:
            UnavailableFriday.append(self.name)
            self.friday = "Unavailable"

        SaturdayAvailable = input("Are you available on Saturday? Enter 'Available' if you are:" )
        if SaturdayAvailable == "Available":
            AvailableSaturday.append(self.name)
        elif SaturdayAvailable == "Preferred":
            self.saturday = "Preferred"
            AvailableSaturday.append(self.name)
        else:
            UnavailableSaturday.append(self.name)
            self.saturday = "Unavailable"

        
class CustomHTMLCalendar(calendar.HTMLCalendar):
    def __init__(self, events=None):
        super().__init__(calendar.SUNDAY)  # Start the week on Sunday
        self.events = events or {}  # Dictionary to hold events for specific dates

    def set_events(self, events):
        """Set or update events. Events should be a dictionary in the form {date: text}."""
        self.events = events

    def formatday(self, day, weekday):
        """Customize the format of each day."""
        if day == 0:
            # Day outside of the current month
            return '<td class="noday">&nbsp;</td>'
        else:
            # Add event text below the day number
            event_text = self.events.get(day, "")  # Get event for the day, if available
            return f'''
                <td class="{self.cssclasses[weekday]}">
                    <div>{day}</div>
                    <div style="font-size: small; color: gray;">{event_text}</div>
                </td>
            '''

    def formatmonth(self, year, month):
        """Generate the complete month's calendar as an HTML table."""
        return super().formatmonth(year, month)


# Example usage
if __name__ == "__main__":
    # Define some events

    AvailableSunday = []
    UnavailableSunday = []
    AvailableMonday = []
    UnavailableMonday = []
    AvailableTuesday = []
    UnavailableTuesday = []
    AvailableWednesday = []
    UnavailableWednesday = []
    AvailableThursday = []
    UnavailableThursday = []
    AvailableFriday = []
    UnavailableFriday = []
    AvailableSaturday = []
    UnavailableSaturday = []

    caregiver1info = Caregiver("Mary", "577-414-4477", "maryb@gmail.com", 20, 10)
    caregiver2info = Caregiver("Pamela", "339-546-0467", "pam1952@gmail.com", 0, 10)
    caregiver3info = Caregiver("Paulene", "766-679-3324", "paulene1971@gmail.com", 0, 10)
    caregiver4info = Caregiver("Michaela", "954-642-1751", "michaela1994@gmail.com", 20, 10)
    caregiver5info = Caregiver("May", "606-458-4587", "mayc2002@gmail.com", 20, 10)
    caregiver6info = Caregiver("Jessa", "464-237-7612", "jessmadalyn@gmail.com", 0, 10)
    caregiver7info = Caregiver("Fae", "944-258-7552", "faed2000@gmail.com", 20, 10)
    caregiver8info = Caregiver("Iola", "433-974-2129", "iola12423@gmail.com", 20, 10)

    caregiver1schedule = AvailabilitySchedule("Mary")
    caregiver1schedule.CreateAvailabilitySchedule()
    caregiver1schedule.get_schedule()
    caregiver2schedule = AvailabilitySchedule("Pamela")
    caregiver2schedule.CreateAvailabilitySchedule()
    caregiver2schedule.get_schedule()
    caregiver3schedule = AvailabilitySchedule("Paulene")
    caregiver3schedule.CreateAvailabilitySchedule()
    caregiver3schedule.get_schedule()
    caregiver4schedule = AvailabilitySchedule("Michaela")
    caregiver4schedule.CreateAvailabilitySchedule()
    caregiver4schedule.get_schedule()
    caregiver5schedule = AvailabilitySchedule("May")
    caregiver5schedule.CreateAvailabilitySchedule()
    caregiver5schedule.get_schedule()
    caregiver6schedule = AvailabilitySchedule("Jessa")
    caregiver6schedule.CreateAvailabilitySchedule()
    caregiver6schedule.get_schedule()
    caregiver7schedule = AvailabilitySchedule("Fae")
    caregiver7schedule.CreateAvailabilitySchedule()
    caregiver7schedule.get_schedule()
    caregiver8schedule = AvailabilitySchedule("Iola")
    caregiver8schedule.CreateAvailabilitySchedule()
    caregiver8schedule.get_schedule()
    
    events = {
        1: f"7 AM - 1 PM: {random.choice(AvailableFriday)} <br> 1 PM - 7 PM: {random.choice(AvailableFriday)}",
        2: f"7 AM - 1 PM: {random.choice(AvailableSaturday)}<br> 1 PM - 7 PM: {random.choice(AvailableSaturday)}",
        3: f"7 AM - 1 PM: {random.choice(AvailableSunday)}<br> 1 PM - 7 PM: {random.choice(AvailableSunday)}",
        4: f"7 AM - 1 PM: {random.choice(AvailableMonday)}<br> 1 PM - 7 PM: {random.choice(AvailableMonday)}",
        5: f"7 AM - 1 PM: {random.choice(AvailableTuesday)}<br> 1 PM - 7 PM: {random.choice(AvailableTuesday)}",
        6: f"7 AM - 1 PM: {random.choice(AvailableWednesday)}<br> 1 PM - 7 PM: {random.choice(AvailableWednesday)}",
        7: f"7 AM - 1 PM: {random.choice(AvailableThursday)}<br> 1 PM - 7 PM: {random.choice(AvailableThursday)}",
        8: f"7 AM - 1 PM: {random.choice(AvailableFriday)}<br> 1 PM - 7 PM: {random.choice(AvailableFriday)}",
        9: f"7 AM - 1 PM: {random.choice(AvailableSaturday)}<br> 1 PM - 7 PM: {random.choice(AvailableSaturday)}",
        10: f"7 AM - 1 PM: {random.choice(AvailableSunday)}<br> 1 PM - 7 PM: {random.choice(AvailableSunday)}",
        11: f"7 AM - 1 PM: {random.choice(AvailableMonday)}<br> 1 PM - 7 PM: {random.choice(AvailableMonday)}",
        12: f"7 AM - 1 PM: {random.choice(AvailableTuesday)}<br> 1 PM - 7 PM: {random.choice(AvailableTuesday)}",
        13: f"7 AM - 1 PM: {random.choice(AvailableWednesday)}<br> 1 PM - 7 PM: {random.choice(AvailableWednesday)}",
        14: f"7 AM - 1 PM: {random.choice(AvailableThursday)}<br> 1 PM - 7 PM: {random.choice(AvailableThursday)}",
        15: f"7 AM - 1 PM: {random.choice(AvailableFriday)}<br> 1 PM - 7 PM: {random.choice(AvailableFriday)}",
        16: f"7 AM - 1 PM: {random.choice(AvailableSaturday)}<br> 1 PM - 7 PM: {random.choice(AvailableSaturday)}",
        17: f"7 AM - 1 PM: {random.choice(AvailableSunday)}<br> 1 PM - 7 PM: {random.choice(AvailableSunday)}",
        18: f"7 AM - 1 PM: {random.choice(AvailableMonday)}<br> 1 PM - 7 PM: {random.choice(AvailableMonday)}",
        19: f"7 AM - 1 PM: {random.choice(AvailableTuesday)}<br> 1 PM - 7 PM: {random.choice(AvailableTuesday)}",
        20: f"7 AM - 1 PM: {random.choice(AvailableWednesday)}<br> 1 PM - 7 PM: {random.choice(AvailableWednesday)}",
        21: f"7 AM - 1 PM: {random.choice(AvailableThursday)}<br> 1 PM - 7 PM: {random.choice(AvailableThursday)}",
        22: f"7 AM - 1 PM: {random.choice(AvailableFriday)}<br> 1 PM - 7 PM: {random.choice(AvailableFriday)}",
        23: f"7 AM - 1 PM: {random.choice(AvailableSaturday)}<br> 1 PM - 7 PM: {random.choice(AvailableSaturday)}",
        24: f"7 AM - 1 PM: {random.choice(AvailableSunday)}<br> 1 PM - 7 PM: {random.choice(AvailableSunday)}",
        25: f"7 AM - 1 PM: {random.choice(AvailableMonday)}<br> 1 PM - 7 PM: {random.choice(AvailableMonday)}",
        26: f"7 AM - 1 PM: {random.choice(AvailableTuesday)}<br> 1 PM - 7 PM: {random.choice(AvailableTuesday)}",
        27: f"7 AM - 1 PM: {random.choice(AvailableWednesday)}<br> 1 PM - 7 PM: {random.choice(AvailableWednesday)}",
        28: f"7 AM - 1 PM: {random.choice(AvailableThursday)}<br> 1 PM - 7 PM: {random.choice(AvailableThursday)}",
        29: f"7 AM - 1 PM: {random.choice(AvailableFriday)}<br> 1 PM - 7 PM: {random.choice(AvailableFriday)}",
        30: f"7 AM - 1 PM: {random.choice(AvailableSaturday)}<br> 1 PM - 7 PM:{random.choice(AvailableSaturday)}",
    }

    # Create a custom calendar instance
    custom_calendar = CustomHTMLCalendar(events)

    # Generate the calendar for November 2024
    calendar_html = custom_calendar.formatmonth(2024, 11)

    # Save to file
    with open("calendar.html", "w") as file:
        file.write(f"""
        <!DOCTYPE html>
        <html lang="en">
        <head>
            <meta charset="UTF-8">
            <meta name="viewport" content="width=device-width, initial-scale=1.0">
            <title>Custom Calendar</title>
            <style>
                table {{
                    width: 100%;
                    border-collapse: collapse;
                    margin: 20px 0;
                }}
                th, td {{
                    border: 1px solid #ddd;
                    text-align: center;
                    padding: 8px;
                }}
                th {{
                    background-color: #f4f4f4;
                }}
                td {{
                    height: 80px;
                    vertical-align: top;
                }}
                td div {{
                    margin: 2px 0;
                }}
            </style>
        </head>
        <body>
            {calendar_html}
        </body>
        </html>
        """)

    print("Caregiving calendar saved to 'calendar.html'")
# Out:
# Is Mary available on Sunday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular: Available
# Is Mary available on Monday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular:
# Is Mary available on Tuesday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular: Available
# Is Mary available on Wednesday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular: Available
# Is Mary available on Thursday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular: Available
# Is Mary available on Friday? Enter 'Available,' or 'Preferred' if they prefer to work that day in particular: Available
# Are you available on Saturday? Enter 'Available' if you are: Available
# Caregiver name: Mary
# Availability:
# Monday: Unavailable
# Tuesday: Available
# Wednesday: Available
# Thursday: Available
# Friday: Available
# Saturday: Available
# Sunday: Available
# ...

# %% [markdown]
# ### Notebook Instructions
# > Before turning in your notebook:
# > 1. Make sure you have renamed the notebook file as instructed
# > 2. Make sure you have included your signature block and that it is correct according to the instructions
# > 3. comment your code as necessary
# > 4. run all code cells and double check that they run correctly. If you can't get your code to run correctly and you want partial credit, add a note for the grader in a new markdown cell directly above your code solution.<br><br>
# Turn in your notebook by uploading it to ELMS<br>
# IF the exercises involve saved data files, put your notebook and the data file(s) in a zip folder and upload the zip folder to ELMS
